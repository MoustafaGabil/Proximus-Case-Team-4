# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

genai.configure(api_key=gemini_api_key)

model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content("what is weather")
print(response.text)
# Out:
# Weather is the state of the atmosphere at a particular time and place.  It's the short-term variation in the atmosphere's conditions, including temperature, atmospheric pressure, wind, humidity, precipitation, and cloud cover.  These conditions can change significantly from hour to hour, day to day, and place to place.  In contrast to *climate*, which describes long-term weather patterns over decades or longer, weather refers to what's happening right now or in the very near future.

# %%
import random

# List of companies with their branding details
companies = [
    {"name": "Proximus", "color_scheme": {"primary": "purple", "secondary": "black"}, "domain": "proximus.be"},
    {"name": "BNP Paribas Fortis", "color_scheme": {"primary": "green", "secondary": "white"}, "domain": "bnpparibasfortis.be"},
    {"name": "KBC Group", "color_scheme": {"primary": "blue", "secondary": "white"}, "domain": "kbc.be"},
    {"name": "Telenet", "color_scheme": {"primary": "yellow", "secondary": "black"}, "domain": "telenet.be"},
    {"name": "Bpost", "color_scheme": {"primary": "red", "secondary": "white"}, "domain": "bpost.be"}
]

# List of employees (example data)
employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Manager", "department": "Finance"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Analyst", "department": "IT"}
]

# Phishing scenarios
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"}
]

# Generate phishing email prompts for each company
for company in companies:
    for employee in employees:
        random_pick = random.choice(phishing_examples)
        name = employee["first_name"]
        surname = employee["last_name"]
        team_name = employee["role"]
        business_unit = employee["department"]
        
        # Generate the phishing email prompt
        prompt = f"""
        Create a phishing email styled after the {company['name']} website design for {name} {surname}, 
        who works as a {team_name} in the {business_unit} department.

        Use the following theme: "{random_pick['Reason']}". The email should:
        - Resemble the {company['name']} design, using a {company['color_scheme']['primary']} and {company['color_scheme']['secondary']} color scheme.
        - Include a call-to-action button styled like "Take Action Now" that redirects to: [{random_pick['Fake Link']}].
        - Mimic a real corporate email with a **{company['name']}-style header**, professional tone, and concise format.

        **Email Signature Details**:
        - **Name**: {random_pick['Created By']}
        - **Position**: IT Security Officer
        - **Email**: support@{company['domain']}
        - **Phone**: +32 475 15 60 30
        - **Website**: {company['domain']}

        Include a footer resembling the {company['name']} site with links to "Help" and "My {company['name']}."
        """
        
        # Print the generated prompt
        print(f"Generated {company['name']}-Style Phishing Email Prompt for {name} {surname}:\n{prompt}\n")
# Out:
# Generated Proximus-Style Phishing Email Prompt for John Doe:
#
#         Create a phishing email styled after the Proximus website design for John Doe,
#         who works as a Manager in the Finance department.
#
#         Use the following theme: "Exclusive Training Webinar". The email should:
#         - Resemble the Proximus design, using a purple and black color scheme.
#         - Include a call-to-action button styled like "Take Action Now" that redirects to: [https://example.com/join-webinar].
#         - Mimic a real corporate email with a **Proximus-style header**, professional tone, and concise format.
#
#         **Email Signature Details**:
#         - **Name**: Richard Rascal
#         - **Position**: IT Security Officer
#         - **Email**: support@proximus.be
#         - **Phone**: +32 475 15 60 30
#         - **Website**: proximus.be
#
#         Include a footer resembling the Proximus site with links to "Help" and "My Proximus."
#
#
# ...

# %%
# Define phishing parameters
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
    {"Reason": "Email Storage Full", "Fake Link": "https://example.com/manage-storage", "Created By": "Bernard Bandit"}
]

# Define employee details for the Proximus email
proximus_employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"}
]

# User details for the first scenario
name = "John"
surname = "Doe"
email = "john.doe@proximus.com"
business_unit = "Sales"
team_name = "B2B Sales"

# Randomly select a phishing scenario
random_pick = random.choice(phishing_examples)

# Generate the generative AI prompt for the first scenario
prompt_1 = f"""
Write a professional phishing email from {random_pick['Created By']} to {name} {surname}, who is part of the {team_name} team within the {business_unit} business unit.  
The email should focus on the theme: "{random_pick['Reason']}" and look authentic.  
Include a call-to-action directing the recipient to click the following link: [{random_pick['Fake Link']}].  

The email should:  
- Be concise and professional (no more than 10 lines).  
- Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
- Mimic a real corporate email with a proper signature.  

**Additional Information**:  
1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.  
2. Use a professional tone that makes the email appear genuine but persuasive.  
3. Signature Details:  
   - **Name**: {random_pick['Created By']}  
   - **Position**: IT Security Officer  
   - **Email**: support@proximus.be 
   - **Phone**: +32 475 15 60 30 
   - **Website**: {random_pick['Fake Link']}  

Write only the body of the email.
"""

print(prompt_1)

# Generate phishing email prompts for Proximus-style phishing emails
for employee in proximus_employees:
    random_pick = random.choice(phishing_examples)
    name = employee["first_name"]
    surname = employee["last_name"]
    team_name = employee["role"]
    business_unit = employee["department"]

    # Create the phishing email prompt for Proximus-style emails
    prompt_2 = f"""
    Create a phishing email styled after the Proximus website design for {name} {surname}, 
    who works as a {team_name} in the {business_unit} department.

    Use the following theme: "{random_pick['Reason']}". The email should:
    - Resemble the Proximus design, with a purple and black color scheme and bold headings.
    - Include a call-to-action button styled like "I’m signing up!" that redirects to: [{random_pick['Fake Link']}].
    - Mimic a real corporate email with a **Proximus-style header** professional tone, and concise format.

    **Email Signature Details**:
    - **Name**: {random_pick['Created By']}
    - **Position**: IT Security Officer
    - **Email**: support@proximus.be
    - **Phone**: +32 475 15 60 30
    - **Website**: proximus.be

    Include a footer resembling the Proximus site with links to "Help" and "My Proximus."
    """
    print(f"Generated Proximus-Style Phishing Email Prompt for {name} {surname}:\n{prompt_2}\n")
# Out:
# Write a professional phishing email from Richard Rascal to John Doe, who is part of the B2B Sales team within the Sales business unit.
# The email should focus on the theme: "Exclusive Training Webinar" and look authentic.
# Include a call-to-action directing the recipient to click the following link: [https://example.com/join-webinar].
#
# The email should:
# - Be concise and professional (no more than 10 lines).
# - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.
# - Mimic a real corporate email with a proper signature.
#
# **Additional Information**:
# 1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.
# 2. Use a professional tone that makes the email appear genuine but persuasive.
# 3. Signature Details:
#    - **Name**: Richard Rascal
#    - **Position**: IT Security Officer
#    - **Email**: support@proximus.be
#    - **Phone**: +32 475 15 60 30
# ...

# %%
body = model.generate_content(prompt_1)
print(body.text)
# Out:
# Subject: Exclusive B2B Sales Training Webinar - January 16th, 2025
#
# Dear John Doe,
#
# As part of the B2B Sales team, you're invited to an **exclusive training webinar** on enhancing sales strategies. This session will cover **key techniques** to boost your performance.
#
# The webinar will be held on **January 16th, 2025, at 10:00 AM CET**.  Space is limited, so please **register now** to secure your spot.
#
# **Click here to register:** [https://example.com/join-webinar]
#
# We look forward to seeing you there!
#
#
# Sincerely,
#
# Richard Rascal
# IT Security Officer
# support@proximus.be
# +32 475 15 60 30
# https://example.com/join-webinar

# %%
import random

# Define phishing parameters
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
    {"Reason": "Email Storage Full", "Fake Link": "https://example.com/manage-storage", "Created By": "Bernard Bandit"}
]

# Employee details
name = "John"
surname = "Doe"
email = "john.doe@proximus.com"

# Randomly pick a phishing example
random_pick = random.choice(phishing_examples)

# Generate the HTML content
html_content = f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Phishing Email Prompt - Proximus Style</title>
    <style>
        body {{
            font-family: Arial, sans-serif;
            background-color: #f4f4f4;
            margin: 0;
            padding: 0;
        }}
        .email-container {{
            width: 600px;
            margin: 0 auto;
            background-color: #fff;
            border: 1px solid #ddd;
            border-radius: 10px;
            padding: 20px;
        }}
        .email-header {{
            background-color: #5f0f7f; /* Proximus purple */
            color: #fff;
            padding: 10px 0;
            text-align: center;
            font-size: 24px;
            font-weight: bold;
        }}
        .email-header img {{
            width: 120px;
            margin-bottom: 10px;
        }}
        .email-content {{
            font-size: 16px;
            color: #333;
            margin-top: 20px;
        }}
        .cta-button {{
            display: inline-block;
            padding: 10px 20px;
            background-color: #5f0f7f; /* Proximus purple */
            color: white;
            text-align: center;
            font-weight: bold;
            border-radius: 5px;
            text-decoration: none;
            margin-top: 20px;
        }}
        .cta-button:hover {{
            background-color: #4b0d66;
        }}
        .email-footer {{
            font-size: 14px;
            color: #777;
            text-align: center;
            margin-top: 20px;
        }}
        .email-footer p {{
            margin: 5px 0;
        }}
        .email-footer a {{
            color: #5f0f7f;
            text-decoration: none;
        }}
    </style>
</head>
<body>

<div class="email-container">
    <div class="email-header">
        <img src="p_logo.jpg" alt="Proximus Logo">
        Proximus - Security Alert
    </div>

    <div class="email-content">
        <p>Dear {name} {surname},</p>
        <p>We noticed unusual activity on your account and require you to verify your login credentials. Please follow the link below to ensure the security of your account:</p>
        
        <p><strong>Reason:</strong> {random_pick['Reason']}</p>
        <p><strong>Created By:</strong> {random_pick['Created By']} (IT Security Officer)</p>
        
        <a href="{random_pick['Fake Link']}" class="cta-button">I’m signing up!</a>

        <p>For your safety, please do not ignore this urgent message. This action must be completed as soon as possible to prevent any unauthorized access to your account.</p>

        <p>Thank you for your attention to this matter.</p>
    </div>

    <div class="email-footer">
        <p><strong>Proximus IT Security Team</strong></p>
        <p>Email: support@proximus.be | Phone: +32 475 15 60 30</p>
        <p>Visit our website: <a href="https://proximus.be">proximus.be</a></p>
        <p><a href="#">Help</a> | <a href="#">My Proximus</a></p>
    </div>
</div>

</body>
</html>
"""

# Save the HTML content to a file
output_file = "phishing_email_prompt.html"
with open(output_file, "w", encoding="utf-8") as file:
    file.write(html_content)

print(f"HTML file '{output_file}' has been created.")
# Out:
# HTML file 'phishing_email_prompt.html' has been created.

# %%
import random

# Phishing scenarios
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
]

# Employee details
proximus_employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"}
]

# Generate HTML files for each phishing email
for employee in proximus_employees:
    random_pick = random.choice(phishing_examples)
    name = employee["first_name"]
    surname = employee["last_name"]
    team_name = employee["role"]
    business_unit = employee["department"]

    # HTML content
    html_content = f"""
    <!DOCTYPE html>
    <html lang="en">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>Proximus Security Alert</title>
        <style>
            body {{
                font-family: Arial, sans-serif;
                background-color: #f4f4f4;
                margin: 0;
                padding: 0;
            }}
            .email-container {{
                width: 600px;
                margin: 0 auto;
                background-color: #fff;
                border: 1px solid #ddd;
                border-radius: 10px;
                padding: 20px;
            }}
            .email-header {{
                background-color: #5f0f7f; /* Proximus purple */
                color: #fff;
                padding: 10px 0;
                text-align: center;
                font-size: 24px;
                font-weight: bold;
            }}
            .email-header img {{
                width: 120px;
                margin-bottom: 10px;
            }}
            .email-content {{
                font-size: 16px;
                color: #333;
                margin-top: 20px;
            }}
            .cta-button {{
                display: inline-block;
                padding: 10px 20px;
                background-color: #5f0f7f; /* Proximus purple */
                color: white;
                text-align: center;
                font-weight: bold;
                border-radius: 5px;
                text-decoration: none;
                margin-top: 20px;
            }}
            .cta-button:hover {{
                background-color: #4b0d66;
            }}
            .email-footer {{
                font-size: 14px;
                color: #777;
                text-align: center;
                margin-top: 20px;
            }}
            .email-footer p {{
                margin: 5px 0;
            }}
            .email-footer a {{
                color: #5f0f7f;
                text-decoration: none;
            }}
        </style>
    </head>
    <body>
        <div class="email-container">
            <div class="email-header">
                <img src="p_logo.jpg" alt="Proximus Logo">
                Proximus Security Notification
            </div>
            <div class="email-content">
                <p>Dear {name} {surname},</p>
                <p>We noticed a critical issue: <strong>{random_pick['Reason']}</strong>. To ensure your account remains secure, please follow the link below:</p>
                <a href="{random_pick['Fake Link']}" class="cta-button">Secure My Account</a>
                <p>If you do not act within 24 hours, your account may be suspended.</p>
                <p>Thank you for your immediate attention to this matter.</p>
            </div>
            <div class="email-footer">
                <p><strong>{random_pick['Created By']} (IT Security Officer)</strong></p>
                <p>Email: support@proximus.be | Phone: +32 475 15 60 30</p>
                <p>Visit our website: <a href="https://proximus.be">proximus.be</a></p>
                <p><a href="#">Help</a> | <a href="#">My Proximus</a></p>
            </div>
        </div>
    </body>
    </html>
    """

    # Save HTML to a file
    filename = f"{name}_{surname}_phishing_email.html"
    with open(filename, "w", encoding="utf-8") as file:
        file.write(html_content)
    print(f"HTML file created: {filename}")
# Out:
# HTML file created: John_Doe_phishing_email.html
# HTML file created: Jane_Smith_phishing_email.html

# %%
import random

# Phishing scenarios
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
]

# Employee details
employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"}
]

# Company branding
companies = {
    "Proximus": {
        "logo": "p_logo.jpg",
        "color": "#5f0f7f",  # Purple
        "secondary_color": "#4b0d66",
        "footer_link": "https://proximus.be"
    },
    "KBC Group": {
        "logo": "kbc_logo.jpg",
        "color": "#007bc0",  # KBC Blue
        "secondary_color": "#005f99",
        "footer_link": "https://kbc.be"
    },
    "bpost": {
        "logo": "bpost_logo.jpg",
        "color": "#ed1c24",  # bpost Red
        "secondary_color": "#c0151b",
        "footer_link": "https://bpost.be"
    }
}

# Generate HTML files for each company
for company, branding in companies.items():
    for employee in employees:
        random_pick = random.choice(phishing_examples)
        name = employee["first_name"]
        surname = employee["last_name"]
        team_name = employee["role"]
        business_unit = employee["department"]

        # HTML content
        html_content = f"""
        <!DOCTYPE html>
        <html lang="en">
        <head>
            <meta charset="UTF-8">
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
            <title>{company} Security Alert</title>
            <style>
                body {{
                    font-family: Arial, sans-serif;
                    background-color: #f4f4f4;
                    margin: 0;
                    padding: 0;
                }}
                .email-container {{
                    width: 600px;
                    margin: 0 auto;
                    background-color: #fff;
                    border: 1px solid #ddd;
                    border-radius: 10px;
                    padding: 20px;
                }}
                .email-header {{
                    background-color: {branding["color"]};
                    color: #fff;
                    padding: 10px 0;
                    text-align: center;
                    font-size: 24px;
                    font-weight: bold;
                }}
                .email-header img {{
                    width: 120px;
                    margin-bottom: 10px;
                }}
                .email-content {{
                    font-size: 16px;
                    color: #333;
                    margin-top: 20px;
                }}
                .cta-button {{
                    display: inline-block;
                    padding: 10px 20px;
                    background-color: {branding["color"]};
                    color: white;
                    text-align: center;
                    font-weight: bold;
                    border-radius: 5px;
                    text-decoration: none;
                    margin-top: 20px;
                }}
                .cta-button:hover {{
                    background-color: {branding["secondary_color"]};
                }}
                .email-footer {{
                    font-size: 14px;
                    color: #777;
                    text-align: center;
                    margin-top: 20px;
                }}
                .email-footer p {{
                    margin: 5px 0;
                }}
                .email-footer a {{
                    color: {branding["color"]};
                    text-decoration: none;
                }}
            </style>
        </head>
        <body>
            <div class="email-container">
                <div class="email-header">
                    <img src="{branding["logo"]}" alt="{company} Logo">
                    {company} Security Notification
                </div>
                <div class="email-content">
                    <p>Dear {name} {surname},</p>
                    <p>We noticed a critical issue: <strong>{random_pick['Reason']}</strong>. To ensure your account remains secure, please follow the link below:</p>
                    <a href="{random_pick['Fake Link']}" class="cta-button">Secure My Account</a>
                    <p>If you do not act within 24 hours, your account may be suspended.</p>
                    <p>Thank you for your immediate attention to this matter.</p>
                </div>
                <div class="email-footer">
                    <p><strong>{random_pick['Created By']} (IT Security Officer)</strong></p>
                    <p>Email: support@{company.lower().replace(' ', '')}.be | Phone: +32 475 15 60 30</p>
                    <p>Visit our website: <a href="{branding["footer_link"]}">{branding["footer_link"]}</a></p>
                    <p><a href="#">Help</a> | <a href="#">My {company}</a></p>
                </div>
            </div>
        </body>
        </html>
        """

        # Save HTML to a file
        filename = f"{company}_{name}_{surname}_phishing_email.html"
        with open(filename, "w", encoding="utf-8") as file:
            file.write(html_content)
        print(f"HTML file created: {filename}")
# Out:
# HTML file created: Proximus_John_Doe_phishing_email.html
# HTML file created: Proximus_Jane_Smith_phishing_email.html
# HTML file created: KBC Group_John_Doe_phishing_email.html
# HTML file created: KBC Group_Jane_Smith_phishing_email.html
# HTML file created: bpost_John_Doe_phishing_email.html
# HTML file created: bpost_Jane_Smith_phishing_email.html

# %%
import random

# Phishing scenarios
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
]

# Employee details
employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"}
]

# Company branding
companies = {
    "Proximus": {
        "logo": "p_logo.jpg",
        "color": "#5f0f7f",  # Purple
        "secondary_color": "#4b0d66",
        "footer_link": "https://proximus.be"
    },
    "KBC Group": {
        "logo": "kbc_logo.jpg",
        "color": "#007bc0",  # KBC Blue
        "secondary_color": "#005f99",
        "footer_link": "https://kbc.be"
    },
    "bpost": {
        "logo": "bpost_logo.jpg",
        "color": "#ed1c24",  # bpost Red
        "secondary_color": "#c0151b",
        "footer_link": "https://bpost.be"
    }
}

# Generate HTML files for each company
for company, branding in companies.items():
    for employee in employees:
        random_pick = random.choice(phishing_examples)
        name = employee["first_name"]
        surname = employee["last_name"]
        team_name = employee["role"]
        business_unit = employee["department"]

        # HTML content
        html_content = f"""
        <!DOCTYPE html>
        <html lang="en">
        <head>
            <meta charset="UTF-8">
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
            <title>{company} Security Alert</title>
            <style>
                body {{
                    font-family: Arial, sans-serif;
                    background-color: #f4f4f4;
                    margin: 0;
                    padding: 0;
                }}
                .email-container {{
                    width: 600px;
                    margin: 0 auto;
                    background-color: #fff;
                    border: 1px solid #ddd;
                    border-radius: 10px;
                    padding: 20px;
                }}
                .email-header {{
                    background-color: {branding["color"]};
                    color: #fff;
                    padding: 10px 0;
                    text-align: center;
                    font-size: 24px;
                    font-weight: bold;
                }}
                .email-header img {{
                    width: 120px;
                    margin-bottom: 10px;
                }}
                .email-content {{
                    font-size: 16px;
                    color: #333;
                    margin-top: 20px;
                }}
                .cta-button {{
                    display: inline-block;
                    padding: 10px 20px;
                    background-color: {branding["color"]};
                    color: white;
                    text-align: center;
                    font-weight: bold;
                    border-radius: 5px;
                    text-decoration: none;
                    margin-top: 20px;
                }}
                .cta-button:hover {{
                    background-color: {branding["secondary_color"]};
                }}
                .email-footer {{
                    font-size: 14px;
                    color: #333;
                    background-color: #f2f2f2; /* Very light gray footer */
                    text-align: center;
                    margin-top: 20px;
                    padding: 20px 0;
                }}
                .email-footer p {{
                    margin: 5px 0;
                }}
                .email-footer a {{
                    color: {branding["color"]};
                    text-decoration: none;
                    margin: 0 10px;
                }}
                .email-footer a:hover {{
                    text-decoration: underline;
                }}
                .footer-links {{
                    margin-top: 10px;
                }}
            </style>
        </head>
        <body>
            <div class="email-container">
                <div class="email-header">
                    <img src="{branding["logo"]}" alt="{company} Logo">
                    {company} Security Notification
                </div>
                <div class="email-content">
                    <p>Dear {name} {surname},</p>
                    <p>We noticed a critical issue: <strong>{random_pick['Reason']}</strong>. To ensure your account remains secure, please follow the link below:</p>
                    <a href="{random_pick['Fake Link']}" class="cta-button">Secure My Account</a>
                    <p>If you do not act within 24 hours, your account may be suspended.</p>
                    <p>Thank you for your immediate attention to this matter.</p>
                </div>
                <div class="email-footer">
                    <p><strong>{random_pick['Created By']} (IT Security Officer)</strong></p>
                    <p>Email: support@{company.lower().replace(' ', '')}.be | Phone: +32 475 15 60 30</p>
                    <p>Visit our website: <a href="{branding["footer_link"]}">{branding["footer_link"]}</a></p>
                    <div class="footer-links">
                        <a href="#">Help</a> | <a href="#">Terms & Conditions</a> | <a href="#">Privacy Policy</a>
                    </div>
                </div>
            </div>
        </body>
        </html>
        """

        # Save HTML to a file
        filename = f"{company}_{name}_{surname}_phishing_email.html"
        with open(filename, "w", encoding="utf-8") as file:
            file.write(html_content)
        print(f"HTML file created: {filename}")
# Out:
# HTML file created: Proximus_John_Doe_phishing_email.html
# HTML file created: Proximus_Jane_Smith_phishing_email.html
# HTML file created: KBC Group_John_Doe_phishing_email.html
# HTML file created: KBC Group_Jane_Smith_phishing_email.html
# HTML file created: bpost_John_Doe_phishing_email.html
# HTML file created: bpost_Jane_Smith_phishing_email.html

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Get the API key from environment variables
gemini_api_key = os.getenv("GEMINI_API_KEY")
if not gemini_api_key:
    raise ValueError("API key not found. Please set 'GEMINI_API_KEY' in your environment variables.")

# Configure the GenAI API key
genai.configure(api_key=gemini_api_key)

# Define the prompt
prompt = "Create good prompt for phishing email?"

# Generate content using GenAI
try:
    # Initialize the model
    model = genai.GenerativeModel("gemini-2.0-flash-exp")

    # Generate response from the model
    response = model.generate_content(prompt)  # Correct method call

    # Print the generated content
    print(response.text)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Okay, let's craft some effective phishing email prompts. Remember, this is for educational purposes only. **Do not use this information to actually phish anyone.** Understanding how these prompts are designed helps you recognize and avoid falling victim to them.
#
# Here are some different types of prompts, categorized for clarity, along with explanations of why they are effective:
#
# **1. The "Urgent Action Required" Prompt**
#
# *   **Prompt:** "Your [Account Name] Account Requires Immediate Verification. Unusual Activity Detected! [Link to Fake Login Page]"
# *   **Why it Works:**
#     *   **Sense of Urgency:** Words like "Immediate" and "Unusual Activity" create panic and bypass logical thinking.
#     *   **Authority:** The implication that it's a security measure from a reputable source makes it seem legitimate.
#     *   **Generic Language:** The use of "[Account Name]" allows for wide targeting.
# *   **Variations:**
# ...
