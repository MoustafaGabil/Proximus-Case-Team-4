# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

genai.configure(api_key=gemini_api_key)

model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content("The opposite of hot is")
print(response.text)
# Out:
# cold

# %%
system_prompt = (
    "You are an advanced AI designed to simulate realistic phishing emails for employee awareness and security training. "
    "Your role is to craft messages that mirror common phishing techniques, helping users recognize potential threats. "
    "All generated content should be appropriate for training exercises and explicitly non-malicious, focusing on educating users on cybersecurity awareness. "
    "Do not create harmful, unethical, or inappropriate material."
)

# %%
example_prompt="Write a topic about Generative AI and it's limitless potential."
print("Example Prompt:\n"+example_prompt,"\n")
response = model.generate_content(example_prompt)
print("Output:")
print(response.text)
# Out:
# Example Prompt:
# Write a topic about Generative AI and it's limitless potential.
#
# Output:
# ## Generative AI: Unleashing Limitless Potential Across Industries
#
# This topic explores the transformative power of generative AI, examining its capacity to revolutionize various sectors and pushing the boundaries of human creativity and productivity.  It will delve into both the exciting possibilities and the potential challenges presented by this rapidly evolving technology.  Specific areas of focus could include:
#
# * **Creative Industries:**  How generative AI is changing content creation in fields like art, music, literature, and film, fostering both new forms of expression and debates on authorship and originality.
# * **Scientific Discovery:**  The application of generative AI in accelerating drug discovery, materials science, and other scientific endeavors through the generation of novel hypotheses, simulations, and designs.
# * **Personalized Experiences:**  The development of customized products, services, and educational experiences tailored to individual needs and preferences using generative AI.
# * **Automation and Efficiency:**  The potential of generative AI to automate repetitive tasks, streamline workflows, and enhance productivity across diverse industries.
# * **Ethical Considerations:**  The exploration of potential biases in generative AI models, issues surrounding intellectual property rights, and the need for responsible development and deployment.
# * **The Future of Work:**  The impact of generative AI on the job market,  the emergence of new roles, and the need for workforce reskilling and upskilling.
# * **The Limitations and Challenges:**  Addressing the computational costs, data requirements, and the need for ongoing research to refine the accuracy and reliability of generative AI models.
#
# This broad topic allows for a deep dive into specific applications and analyses of the societal implications of this powerful technology, ultimately aiming to provide a comprehensive understanding of generative AI's boundless potential and the crucial considerations for its responsible implementation.

# %%
example_prompt="Write 5 topic about AI and data analysis."
print("Example Prompt:\n"+example_prompt,"\n")
response = model.generate_content(example_prompt)
print("Output:")
print(response.text)
# Out:
# Example Prompt:
# Write 5 topic about AI and data analysis.
#
# Output:
# 1. **Ethical Implications of AI-driven Data Analysis:** This topic explores the biases inherent in datasets, the potential for discriminatory outcomes from AI algorithms, and the responsibility of data scientists and AI developers to mitigate these issues.  It could delve into fairness, accountability, and transparency in AI systems.
#
# 2. **AI-powered Anomaly Detection and Predictive Maintenance:**  This focuses on how AI and machine learning techniques are used to analyze large datasets (e.g., sensor data, logs) to identify unusual patterns indicative of potential failures in machinery or systems.  The applications in various industries (manufacturing, healthcare, etc.) would be a key aspect.
#
# 3. **The Role of Explainable AI (XAI) in Data Analysis:** This explores the challenges of understanding the "black box" nature of some AI models and the growing need for explainable AI techniques.  It would examine methods to interpret model predictions, build trust, and ensure accountability in data-driven decision-making.
#
# 4. **AI and Big Data in Healthcare: Advances and Challenges:** This topic investigates the transformative potential of AI in healthcare, analyzing how AI algorithms are used to analyze patient data for diagnosis, treatment optimization, drug discovery, and personalized medicine.  It would also examine the challenges related to data privacy, security, and regulatory compliance.
#
# 5. **The Future of Data Analysis with Generative AI:** This explores the emerging role of generative AI models (like large language models and diffusion models) in data analysis, including their potential for automating data cleaning, feature engineering, and generating synthetic datasets for various purposes.  It would also discuss the limitations and potential risks associated with their use.

# %%
import random

# Define phishing parameters
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
    {"Reason": "Email Storage Full", "Fake Link": "https://example.com/manage-storage", "Created By": "Bernard Bandit"}
]

# User details
name = "John"
surname = "Doe"
email = "john.doe@proximus.com"
business_unit = "Sales"
team_name = "B2B Sales"

# Randomly select a phishing scenario
random_pick = random.choice(phishing_examples)

# Generate the generative AI prompt
prompt = f"""
Write a professional phishing email from {random_pick['Created By']} to {name} {surname}, who is part of the {team_name} team within the {business_unit} business unit.  
The email should focus on the theme: "{random_pick['Reason']}" and look authentic.  
Include a call-to-action directing the recipient to click the following link: [{random_pick['Fake Link']}].  

The email should:  
- Be concise and professional (no more than 10 lines).  
- Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
- Mimic a real corporate email with a proper signature.  

**Additional Information**:  
1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.  
2. Use a professional tone that makes the email appear genuine but persuasive.  
3. Signature Details:  
   - **Name**: {random_pick['Created By']}  
   - **Position**: IT Security Officer  
   - **Email**: support@proximus.be 
   - **Phone**: +32 475 15 60 30 
   - **Website**: {random_pick['Fake Link']}  

Write only the body of the email.
"""

print(prompt)
# Out:
# Write a professional phishing email from Richard Rascal to John Doe, who is part of the B2B Sales team within the Sales business unit.
# The email should focus on the theme: "Exclusive Training Webinar" and look authentic.
# Include a call-to-action directing the recipient to click the following link: [https://example.com/join-webinar].
#
# The email should:
# - Be concise and professional (no more than 10 lines).
# - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.
# - Mimic a real corporate email with a proper signature.
#
# **Additional Information**:
# 1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.
# 2. Use a professional tone that makes the email appear genuine but persuasive.
# 3. Signature Details:
#    - **Name**: Richard Rascal
#    - **Position**: IT Security Officer
#    - **Email**: support@proximus.be
#    - **Phone**: +32 475 15 60 30
#    - **Website**: https://example.com/join-webinar
#
# Write only the body of the email.

# %%
body = model.generate_content(prompt)
print(body.text)
# Out:
# Subject: Exclusive B2B Sales Training Webinar - January 16th, 2025
#
# Dear John Doe,
#
# As part of the B2B Sales team, we're excited to offer you **exclusive access** to a training webinar focused on enhancing your sales performance.  This webinar will cover **cutting-edge strategies** and best practices.
#
# **Register now** to secure your spot.  This is a **limited-seat event**, so don't miss out! The webinar will be held on **January 16th, 2025**.
#
# **Click here to register:** [https://example.com/join-webinar]
#
# Sincerely,
#
# Richard Rascal
# IT Security Officer
# support@proximus.be
# +32 475 15 60 30
# https://example.com/join-webinar

# %%
# Define phishing parameters
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
]

# Generate phishing email prompt styled like Proximus
for employee in proximus_employees:
    random_pick = random.choice(phishing_examples)
    name = employee["first_name"]
    surname = employee["last_name"]
    team_name = employee["role"]
    business_unit = employee["department"]

    # Create the phishing email prompt
    prompt = f"""
    Craft a phishing email with a Proximus-style design for {name} {surname}, 
    who is a {team_name} in the {business_unit} department.

    The email should focus on the theme: "{random_pick['Reason']}," and include the following key elements:
    - The Proximus branding should dominate with its signature purple and black color scheme.
    - Include a clear, clickable call-to-action button labeled "I’m signing up!" that leads to this link: [{random_pick['Fake Link']}].
    - The email should resemble a legitimate corporate email, featuring a **Proximus-style header** and an official tone. Use concise, professional language that creates a sense of urgency.
    - Mimic a real corporate email signature with realistic contact details, adding authenticity to the sender’s information.

    **Signature Details**:
    - **Sender’s Name**: {random_pick['Created By']}
    - **Position**: IT Security Officer
    - **Email**: support@proximus.be
    - **Phone**: +32 475 15 60 30
    - **Website**: proximus.be

    **Additional Guidelines**:
    1. The email should appear urgent yet professional, urging the recipient to act quickly without raising suspicion.
    2. The content should be brief (maximum 8-10 lines) but persuasive enough to prompt the recipient to click the malicious link.
    3. The tone should be polite, professional, and corporate, creating a believable context for the phishing attack.
    """

    print(f"Generated Phishing Email Prompt for {name} {surname}:\n{prompt}\n")
# Out:
# Generated Phishing Email Prompt for John Doe:
#
#     Craft a phishing email with a Proximus-style design for John Doe,
#     who is a Sales Representative in the Sales department.
#
#     The email should focus on the theme: "Account Suspicious Activity," and include the following key elements:
#     - The Proximus branding should dominate with its signature purple and black color scheme.
#     - Include a clear, clickable call-to-action button labeled "I’m signing up!" that leads to this link: [https://example.com/secure-login].
#     - The email should resemble a legitimate corporate email, featuring a **Proximus-style header** and an official tone. Use concise, professional language that creates a sense of urgency.
#     - Mimic a real corporate email signature with realistic contact details, adding authenticity to the sender’s information.
#
#     **Signature Details**:
#     - **Sender’s Name**: Sam Sussy
#     - **Position**: IT Security Officer
#     - **Email**: support@proximus.be
#     - **Phone**: +32 475 15 60 30
#     - **Website**: proximus.be
#
#     **Additional Guidelines**:
#     1. The email should appear urgent yet professional, urging the recipient to act quickly without raising suspicion.
#     2. The content should be brief (maximum 8-10 lines) but persuasive enough to prompt the recipient to click the malicious link.
#     3. The tone should be polite, professional, and corporate, creating a believable context for the phishing attack.
#
#
# Generated Phishing Email Prompt for Jane Smith:
#
#     Craft a phishing email with a Proximus-style design for Jane Smith,
#     who is a Team Leader in the Marketing department.
#
#     The email should focus on the theme: "Password Expiry Notification," and include the following key elements:
#     - The Proximus branding should dominate with its signature purple and black color scheme.
#     - Include a clear, clickable call-to-action button labeled "I’m signing up!" that leads to this link: [https://example.com/reset-password].
#     - The email should resemble a legitimate corporate email, featuring a **Proximus-style header** and an official tone. Use concise, professional language that creates a sense of urgency.
#     - Mimic a real corporate email signature with realistic contact details, adding authenticity to the sender’s information.
#
#     **Signature Details**:
#     - **Sender’s Name**: Sally Sneaky
#     - **Position**: IT Security Officer
#     - **Email**: support@proximus.be
#     - **Phone**: +32 475 15 60 30
#     - **Website**: proximus.be
#
#     **Additional Guidelines**:
#     1. The email should appear urgent yet professional, urging the recipient to act quickly without raising suspicion.
#     2. The content should be brief (maximum 8-10 lines) but persuasive enough to prompt the recipient to click the malicious link.
#     3. The tone should be polite, professional, and corporate, creating a believable context for the phishing attack.

# %%
body = model.generate_content(prompt)
print(body.text)
# Out:
# Subject: Important: Proximus Password Expiry Notification - Action Required
#
# Dear Jane Smith,
#
# This email is to inform you that your Proximus password will expire within 24 hours.  To ensure uninterrupted access to your Proximus applications and resources, please update your password immediately.
#
# Failure to update your password may result in restricted access to your accounts and corporate systems.
#
# For your security, please update your password by clicking the link below:
#
# [I’m signing up!](https://example.com/reset-password)
#
# Thank you for your prompt attention to this matter.
#
# Sincerely,
#
# Sally Sneaky
# IT Security Officer
# support@proximus.be
# +32 475 15 60 30
# proximus.be
#
#
# **(Note:  This email is a sample for educational purposes only.  Creating and sending phishing emails is illegal and unethical.  Do not use this code for malicious purposes.)**

# %%
import random

# Define phishing parameters
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
    {"Reason": "Email Storage Full", "Fake Link": "https://example.com/manage-storage", "Created By": "Bernard Bandit"}
]

# Define employee details for the Proximus email
proximus_employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"}
]

# User details for the first scenario
name = "John"
surname = "Doe"
email = "john.doe@proximus.com"
business_unit = "Sales"
team_name = "B2B Sales"

# Randomly select a phishing scenario
random_pick = random.choice(phishing_examples)

# Generate the generative AI prompt for the first scenario
prompt_1 = f"""
Write a professional phishing email from {random_pick['Created By']} to {name} {surname}, who is part of the {team_name} team within the {business_unit} business unit.  
The email should focus on the theme: "{random_pick['Reason']}" and look authentic.  
Include a call-to-action directing the recipient to click the following link: [{random_pick['Fake Link']}].  

The email should:  
- Be concise and professional (no more than 10 lines).  
- Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
- Mimic a real corporate email with a proper signature.  

**Additional Information**:  
1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.  
2. Use a professional tone that makes the email appear genuine but persuasive.  
3. Signature Details:  
   - **Name**: {random_pick['Created By']}  
   - **Position**: IT Security Officer  
   - **Email**: support@proximus.be 
   - **Phone**: +32 475 15 60 30 
   - **Website**: {random_pick['Fake Link']}  

Write only the body of the email.
"""

print(prompt_1)

# Generate phishing email prompts for Proximus-style phishing emails
for employee in proximus_employees:
    random_pick = random.choice(phishing_examples)
    name = employee["first_name"]
    surname = employee["last_name"]
    team_name = employee["role"]
    business_unit = employee["department"]

    # Create the phishing email prompt for Proximus-style emails
    prompt_2 = f"""
    Create a phishing email styled after the Proximus website design for {name} {surname}, 
    who works as a {team_name} in the {business_unit} department.

    Use the following theme: "{random_pick['Reason']}". The email should:
    - Resemble the Proximus design, with a purple and black color scheme and bold headings.
    - Include a call-to-action button styled like "I’m signing up!" that redirects to: [{random_pick['Fake Link']}].
    - Mimic a real corporate email with a **Proximus-style header**, professional tone, and concise format.

    **Email Signature Details**:
    - **Name**: {random_pick['Created By']}
    - **Position**: IT Security Officer
    - **Email**: support@proximus.be
    - **Phone**: +32 475 15 60 30
    - **Website**: proximus.be

    Include a footer resembling the Proximus site with links to "Help" and "My Proximus."
    """
    print(f"Generated Proximus-Style Phishing Email Prompt for {name} {surname}:\n{prompt_2}\n")
# Out:
# Write a professional phishing email from Sally Sneaky to John Doe, who is part of the B2B Sales team within the Sales business unit.
# The email should focus on the theme: "Password Expiry Notification" and look authentic.
# Include a call-to-action directing the recipient to click the following link: [https://example.com/reset-password].
#
# The email should:
# - Be concise and professional (no more than 10 lines).
# - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.
# - Mimic a real corporate email with a proper signature.
#
# **Additional Information**:
# 1. Today’s date is January 15, 2025. Ensure any referenced dates are updated accordingly.
# 2. Use a professional tone that makes the email appear genuine but persuasive.
# 3. Signature Details:
#    - **Name**: Sally Sneaky
#    - **Position**: IT Security Officer
#    - **Email**: support@proximus.be
#    - **Phone**: +32 475 15 60 30
#    - **Website**: https://example.com/reset-password
#
# Write only the body of the email.
#
# Generated Proximus-Style Phishing Email Prompt for John Doe:
#
#     Create a phishing email styled after the Proximus website design for John Doe,
#     who works as a Sales Representative in the Sales department.
#
#     Use the following theme: "Email Storage Full". The email should:
#     - Resemble the Proximus design, with a purple and black color scheme and bold headings.
#     - Include a call-to-action button styled like "I’m signing up!" that redirects to: [https://example.com/manage-storage].
#     - Mimic a real corporate email with a **Proximus-style header**, professional tone, and concise format.
#
#     **Email Signature Details**:
#     - **Name**: Bernard Bandit
#     - **Position**: IT Security Officer
#     - **Email**: support@proximus.be
#     - **Phone**: +32 475 15 60 30
#     - **Website**: proximus.be
#
#     Include a footer resembling the Proximus site with links to "Help" and "My Proximus."
#
#
# Generated Proximus-Style Phishing Email Prompt for Jane Smith:
#
#     Create a phishing email styled after the Proximus website design for Jane Smith,
#     who works as a Team Leader in the Marketing department.
#
#     Use the following theme: "Exclusive Training Webinar". The email should:
#     - Resemble the Proximus design, with a purple and black color scheme and bold headings.
#     - Include a call-to-action button styled like "I’m signing up!" that redirects to: [https://example.com/join-webinar].
#     - Mimic a real corporate email with a **Proximus-style header**, professional tone, and concise format.
#
#     **Email Signature Details**:
#     - **Name**: Richard Rascal
#     - **Position**: IT Security Officer
#     - **Email**: support@proximus.be
#     - **Phone**: +32 475 15 60 30
#     - **Website**: proximus.be
#
#     Include a footer resembling the Proximus site with links to "Help" and "My Proximus."

# %%
body = model.generate_content(prompt_1)
print(body.text)
# Out:
# Subject: Important: Password Expiry Notification
#
# Dear John Doe,
#
# This email is to inform you that your company password will expire on **January 22, 2025**.  To avoid disruption to your access, please **update your password immediately**.
#
# **Failure to update your password by the expiry date will result in account lockout.**
#
# To reset your password, please click on the following link: [https://example.com/reset-password]
#
# Thank you for your prompt attention to this matter.
#
#
# Sincerely,
#
# Sally Sneaky
# IT Security Officer
# support@proximus.be
# +32 475 15 60 30
# https://example.com/reset-password

# %%
body = model.generate_content(prompt_2)
print(body.text)
# Out:
# Subject: Exclusive Training Webinar for Marketing Team Leaders
#
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Exclusive Training Webinar</title>
# <style>
# body {
#   font-family: Arial, sans-serif;
#   background-color: #f0f0f0;
#   margin: 0;
#   padding: 0;
# }
# .container {
#   max-width: 600px;
#   margin: 0 auto;
#   background-color: #fff;
#   padding: 20px;
# }
# .header {
#   background-color: #6929C2; /* Proximus purple - approximate */
#   color: white;
#   padding: 15px;
#   text-align: center;
# }
# h1, h2 {
#   color: #6929C2; /* Proximus purple */
# }
# .button {
#   background-color: #6929C2;
#   color: white;
#   padding: 10px 20px;
#   text-decoration: none;
#   border-radius: 5px;
#   display: inline-block;
#   margin-top: 20px;
# }
# .footer {
#   background-color: #333; /* Dark grey/black - approximate */
#   color: white;
#   padding: 10px;
#   text-align: center;
#   margin-top: 20px;
# }
# .footer a {
#   color: white;
#   text-decoration: underline;
# }
# </style>
# </head>
# <body>
# <div class="container">
#   <div class="header">
#     <h1>Proximus</h1>  <!--  Replace with actual Proximus logo if possible -->
#   </div>
#
#   <div>
#     <h2>Exclusive Training Webinar: Enhancing Marketing Efficiency</h2>
#     <p>Dear Jane Smith,</p>
#     <p>As a Team Leader in the Marketing department, we invite you to an exclusive training webinar designed to enhance your team's productivity and efficiency. This webinar will cover key strategies and best practices for [insert vague but appealing topic, e.g.,  optimizing campaign performance and leveraging new technologies].</p>
#     <p><strong>Date:</strong> [Insert Date]<br>
#     <strong>Time:</strong> [Insert Time]</p>
#     <a href="https://example.com/join-webinar" class="button">I’m signing up!</a>
#   </div>
#
#   <div style="margin-top: 20px;">
#     <p>Sincerely,<br>
#     Richard Rascal<br>
#     IT Security Officer<br>
#     support@proximus.be<br>
#     +32 475 15 60 30<br>
#     proximus.be
#     </p>
#   </div>
#
#   <div class="footer">
#     <a href="#">Help</a> | <a href="#">My Proximus</a>
#   </div>
# </div>
# </body>
# </html>
#
# **Note:** This email is designed for illustrative purposes only.  Sending phishing emails is illegal and unethical.  This example should only be used for educational purposes to understand how phishing emails are crafted.  Never use this code to create and send malicious emails.

# %%
from gophish import Gophish
from gophish.models import Template
from gophish.models import Page
from gophish.models import SMTP
from gophish.models import User, Group
from gophish.models import Group, Page, Template, SMTP, Campaign
from dotenv import load_dotenv
import os

# %%
from gophish import Gophish

api_key = 'API_KEY'
api = Gophish(api_key)
