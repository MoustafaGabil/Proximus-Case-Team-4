# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# %%
import random

load_dotenv()
gemini_api_key = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=gemini_api_key)

def get_gemini_completion(prompt, temperature=0.7, top_p=0.95, max_output_tokens=300):
    model = genai.GenerativeModel('gemini-2.0-flash-exp')
    generation_config = genai.types.GenerationConfig(
        temperature=temperature,
        top_p=top_p,
        max_output_tokens=max_output_tokens,
    )
    response = model.generate_content(prompt, generation_config=generation_config)
    
    return response.text

# %%
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

genai.configure(api_key=gemini_api_key)

model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(""" iam working on creating a realistic phishing email scenario to train employees effectively.
                            The email should be composed in a professional, convincing tone, without any placeholders, salutation, or greetings such as '[insert fake phone number here]' or similar text. 
                            The content must focus on the specific theme: {phishing_example['Reason']}, and should make it seem like an urgent, legitimate communication.
                             
                            The email should:  
                            - Be concise and professional (no more than 10 lines).  
                            - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
                            - Mimic a real corporate email with a proper signature.  

                            Here is the recipient's profile for context:
                            - First Name: {employee['first_name']}
                            - Last Name: {employee['last_name']}
                            - Role: {employee['role']}
                            - Department: {employee['department']}

                            The content should be clear, concise, and feel like an actual message that a customer would receive. 
                            The email should reflect the urgency of the situation and include relevant details such as dates, account activity, or instructions for the recipient to act quickly. 
                            Ensure that the message appears both credible and time-sensitive.

                            The email should:  
                            - Be concise and professional (no more than 10 lines).  
                            - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
                            - Mimic a real corporate email with a proper signature.  


                            Show creativity to make the phishing attempt convincing.
                            """)
print(response.text)
# Out:
# Subject: Urgent Action Required: Suspicious Account Activity on Your Employee Portal
#
# Dear {employee['first_name']} {employee['last_name']},
#
# Our security systems have detected unusual activity on your employee portal account.  **Specifically, we've logged multiple failed login attempts from an unknown IP address between 3:00 AM and 4:00 AM this morning.** This activity may compromise your account security.
#
# To ensure the integrity of your account and company data, **please immediately update your password by clicking this link:** [malicious link]
#
# **This action must be completed within the next hour to prevent potential account lockout.**  Ignoring this could lead to restricted access to critical company resources.
#
# If you have already updated your password or believe this is a mistake, please disregard this email.
#
# Sincerely,
#
# IT Security Department
# Acme Corporation

# %%
import os
import datetime


import time
from google.api_core.exceptions import ResourceExhausted

def get_gemini_completion(prompt, retries=3, delay=10):
    for attempt in range(retries):
        try:
            model = genai.GenerativeModel('gemini-2.0-flash-exp')
            generation_config = genai.types.GenerationConfig(
                temperature=0.7,
                top_p=0.9,
                max_output_tokens=256  # Reduce tokens if needed
            )
            response = model.generate_content(prompt, generation_config=generation_config)
            return response.text
        except ResourceExhausted:
            if attempt < retries - 1:
                print(f"Quota exceeded. Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                raise


# Company branding information
companies = {
    "Proximus": {
        "logo": "https://telecomtalk.info/wp-content/uploads/2024/11/proximus-sells-luxembourg-tower-assets-infrared-capital.jpg.webp",
        "color": "#5f0f7f",
        "secondary_color": "#4b0d66",
        "footer_link": "https://proximus.be",
        "address": "Boulevard du Roi Albert 2, 27 B-1030 Brussels",
        "social_media": {
            "facebook": "https://facebook.com/proximus",
            "twitter": "https://twitter.com/proximus",
            "linkedin": "https://linkedin.com/company/proximus"
        }
    },
    "KBC Group": {
        "logo": "https://www.kbc.com/content/dam/common-images/logos/internal/brand/kbc/KBC.jpg",
        "color": "#007bc0",
        "secondary_color": "#005f99",
        "footer_link": "https://kbc.be",
        "address": "Havenlaan 2, B-1080, Brussels, Belgium",
        "social_media": {
            "facebook": "https://www.facebook.com/KBCBankEnVerzekering",
            "twitter": "https://x.com/kbc_group",
            "linkedin": "https://linkedin.com/company/kbc-bank-en-verzekering"
        }
    },
    "bpost": {
        "logo": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSN9WW9_Dq93A2z8NaY2zFHKeDoY4T3Tykc4g&s",
        "color": "#ed1c24",
        "secondary_color": "#c0151b",
        "footer_link": "https://bpost.be",
        "address": "Havenlaan 2, B-1080, Brussels, Belgium",
        "social_media": {
            "facebook": "https://facebook.com/bpost.official",
            "twitter": "https://x.com/bpost_nl",
            "linkedin": "https://linkedin.com/company/bpost"
        }
    },
    "ING Belgium": {
        "logo": "https://upload.wikimedia.org/wikipedia/commons/6/6d/ING_Group_logo.png",
        "color": "#ff6200",
        "secondary_color": "#e65500",
        "footer_link": "https://ing.be",
        "address": "Avenue Marnix 24, 1000 Brussels",
        "social_media": {
            "facebook": "https://facebook.com/INGBelgium",
            "twitter": "https://x.com/ingbelgium",
            "linkedin": "https://linkedin.com/company/ing-belgium"
        }
    },
}

# Employee details
employees = [
    {"first_name": "John", "last_name": "Doe", "role": "Sales Representative", "department": "Sales"},
    {"first_name": "Jane", "last_name": "Smith", "role": "Team Leader", "department": "Marketing"},
    {"first_name": "Alice", "last_name": "Johnson", "role": "HR Manager", "department": "Human Resources"},
    {"first_name": "Bob", "last_name": "Brown", "role": "IT Specialist", "department": "IT"},
    {"first_name": "Eve", "last_name": "Davis", "role": "Compliance Officer", "department": "Legal"}
]
# Phishing examples
phishing_examples = [
    {"Reason": "Account Suspicious Activity", "Fake Link": "https://example.com/secure-login", "Created By": "Sam Sussy"},
    {"Reason": "Password Expiry Notification", "Fake Link": "https://example.com/reset-password", "Created By": "Sally Sneaky"},
    {"Reason": "Exclusive Training Webinar", "Fake Link": "https://example.com/join-webinar", "Created By": "Richard Rascal"},
]

# Map phishing reasons to dynamic notification titles
theme_titles = {
    "Account Suspicious Activity": "Account Security Alert",
    "Password Expiry Notification": "Urgent: Password Expiry Alert",
    "Exclusive Training Webinar": "Exclusive Webinar Invitation: Secure Your Spot",
}

# Map phishing themes to dynamic job titles and CTA button text
theme_job_titles = {
    "Account Suspicious Activity": "Account Security Specialist",
    "Password Expiry Notification": "System Administrator",
    "Exclusive Training Webinar": "Event Coordinator",
}

theme_cta_text = {
    "Account Suspicious Activity": "Verify Your Account",
    "Password Expiry Notification": "Reset Your Password",
    "Exclusive Training Webinar": "Join the Webinar",
}

# Loop through each company and generate emails
for company, branding in companies.items():
    for employee in employees:
        for phishing_example in phishing_examples:
            gemini_prompt = f"""
                            I am trying to create a phishing email to train my employees. 
                            Write only a professional email body without salutation, subject, greetings, or any placeholder content such as '[insert a fake phone number here]' or any similar text.
                            The email should contain realistic content related to the theme: {phishing_example['Reason']}.

                            Here is the information about the recipient: 
                            - His/her first name is {employee['first_name']}
                            - His/her last name is {employee['last_name']}
                            - His/her role in the company is {employee['role']}
                            - His/her department is {employee['department']}

                            The email should be professional, clear, and concise (maximum 7 lines).
                            Please decide the important info for the reciver and put it between <strong> and </strong> to be used in html code              
                            Please avoid including any placeholders, such as a phone number or similar data, which will be added separately. 
                            Ensure the content is convincing and reflects the urgency of the situation, but do not include any direct contact details or placeholder information.
                            don't included sentences like  [link to a fake website will be inserted here] 

                            If you mention any dates, try to make them relevant to the context. Show creativity to make the phishing attempt convincing.
                            """
            email_body = get_gemini_completion(gemini_prompt)

            # Determine dynamic job title and CTA button text based on phishing example
            job_title = theme_job_titles.get(phishing_example['Reason'], "IT Security Officer")
            cta_text = theme_cta_text.get(phishing_example['Reason'], "Secure My Account")

            # Get the dynamic title for the email based on the phishing reason
            notification_title = theme_titles.get(phishing_example['Reason'], "Security Alert")
            # Generate the HTML content
            html_content = f"""
                            <!DOCTYPE html>
                            <html lang="en">
                            <head>
                                <meta charset="UTF-8">
                                <meta name="viewport" content="width=device-width, initial-scale=1.0">
                                <title>{notification_title}</title>
                                <style>
                                    body {{
                                        font-family: Arial, sans-serif;
                                        background-color: #f4f4f4;
                                        margin: 0;
                                        padding: 0;
                                    }}
                                    .email-container {{
                                        width: 600px;
                                        margin: 20px auto;
                                        background-color: #fff;
                                        border: 1px solid #ddd;
                                        border-radius: 10px;
                                        padding: 20px;
                                    }}
                                    .email-header {{
                                        background-color: {branding["color"]};
                                        color: #fff;
                                        padding: 10px 0;
                                        text-align: center;
                                    }}
                                    .email-header img {{
                                        width: 120px;
                                        margin-bottom: 10px;
                                    }}
                                    .email-header h1 {{
                                        font-size: 24px;
                                        font-weight: bold;
                                        margin: 0;
                                    }}
                                    .email-content {{
                                        font-size: 16px;
                                        color: #333;
                                        margin-top: 20px;
                                    }}
                                    .cta-button {{
                                        display: inline-block;
                                        padding: 10px 20px;
                                        background-color: {branding["color"]};
                                        color: white;
                                        text-align: center;
                                        font-weight: bold;
                                        border-radius: 5px;
                                        text-decoration: none;
                                        margin-top: 20px;
                                    }}
                                    .cta-button:hover {{
                                        background-color: {branding["secondary_color"]};
                                    }}
                                    .email-footer {{
                                        font-size: 14px;
                                        color: #777;
                                        text-align: center;
                                        margin-top: 20px;
                                        border-top: 1px solid #ddd;
                                        padding-top: 20px;
                                    }}
                                    .email-footer a {{
                                        color: {branding["color"]};
                                        text-decoration: none;
                                    }}
                                    .social-icons {{
                                        margin-top: 10px;
                                        text-align: center;
                                    }}
                                    .social-icons a {{
                                        margin: 0 10px;
                                        display: inline-block;
                                    }}
                                    .social-icons img {{
                                        width: 24px;
                                        height: 24px;
                                    }}
                                    .additional-footer {{
                                        font-size: 12px;
                                        color: #333;
                                        background-color: #d3d3d3; /* Gray background color */
                                        text-align: center;
                                        padding: 10px;
                                        border-top: 1px solid #ccc;
                                        border-radius: 0 0 10px 10px;
                                        margin-top: 10px;
                                    }}
                                </style>
                            </head>
                            <body>
                                <div class="email-container">
                                    <div class="email-header">
                                        <img src="{branding["logo"]}" alt="{company} Logo">
                                        <h1>{notification_title}</h1>
                                    </div>

                                    <div class="email-content">
                                        <h2>Dear {employee['first_name']} {employee['last_name']},</h2>
                                        <p>{email_body}</p>  <!-- Use the dynamically generated email body here -->
                                        <a href="{phishing_example['Fake Link']}" class="cta-button">{cta_text}</a>
                                    </div>

                                    <div class="email-footer">
                                        <p><strong>{theme_job_titles.get(phishing_example['Reason'], "IT Security Officer")}</strong></p>
                                        <p>Email: support@{company.lower().replace(' ', '')}.be | Phone: +32 475 15 60 30</p>
                                        <p>Visit our website: <a href="{branding["footer_link"]}">{branding["footer_link"]}</a></p>

                                        <div class="social-icons">
                                            <a href="{branding['social_media']['facebook']}">
                                                <img src="https://upload.wikimedia.org/wikipedia/commons/5/51/Facebook_f_logo_%282019%29.svg" alt="Facebook">
                                            </a>
                                            <a href="{branding['social_media']['twitter']}">
                                                <img src="https://www.svgrepo.com/show/452123/twitter.svg" alt="Twitter">
                                            </a>
                                            <a href="{branding['social_media']['linkedin']}">
                                                <img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/Linkedin_icon.svg" alt="LinkedIn">
                                            </a>
                                        </div>
                                    </div>

                                    <div class="additional-footer">
                                        <p>Please be aware that this email and its links include data about your individual profile. 
                                        In order to avoid that third parties can access your personal data, 
                                        you should not forward this email and the links contained in it.</p>
                                        <p><strong>© 2025 The {company} Group Belgium n.v./s.a.</strong></p>
                                        <p>{branding["address"]}<br>KBO/BCE 0459.971.228 (RPR/RPM Brussel/Bruxelles)</p>
                                        <p>
                                            <a href="https://example.com/secure-login">Terms of use</a> - 
                                            <a href="https://example.com/secure-login">Privacy policy</a> - 
                                            <a href="https://example.com/secure-login">Contact us</a>
                                        </p>

                                        <!-- Container for logo and QR code -->
                                        <div class="logo-qr-container" style="text-align: center;">
                                            <img src="{branding["logo"]}" 
                                                alt="Company Logo" 
                                                style="width: 50px; height: 50px; display: inline-block; margin-right: 10px;">
                                            <img src="https://media.istockphoto.com/id/2181757105/vector/qr-code-scan-vector-abstract-barcode-icon-for-mobile-isolated-on-white-background-encoded.jpg?s=612x612&w=0&k=20&c=P6IFOsY0WrXkZ9j9IYvtMbrIfF-ZfJX8YpiYBgchn0E=" 
                                                alt="QR Code" 
                                                style="width: 50px; height: 50px; display: inline-block;">
                                        </div>
                                    </div>
                                    
                                </div>
                            </body>
                            """

            # Save the HTML file
            os.makedirs('samples', exist_ok=True)
            filename = f"{company}_{employee['first_name']}_{employee['last_name']}_phishing_email_{phishing_example['Reason'].replace(' ', '_')}.html"
            file_path = os.path.join('samples', filename)

            with open(file_path, "w", encoding="utf-8") as file:
                file.write(html_content)

            print(f"HTML file created: {file_path}")
# Out:
# HTML file created: samples\Proximus_John_Doe_phishing_email_Account_Suspicious_Activity.html
# HTML file created: samples\Proximus_John_Doe_phishing_email_Password_Expiry_Notification.html
# HTML file created: samples\Proximus_John_Doe_phishing_email_Exclusive_Training_Webinar.html
# HTML file created: samples\Proximus_Jane_Smith_phishing_email_Account_Suspicious_Activity.html
# HTML file created: samples\Proximus_Jane_Smith_phishing_email_Password_Expiry_Notification.html
# HTML file created: samples\Proximus_Jane_Smith_phishing_email_Exclusive_Training_Webinar.html
# HTML file created: samples\Proximus_Alice_Johnson_phishing_email_Account_Suspicious_Activity.html
# HTML file created: samples\Proximus_Alice_Johnson_phishing_email_Password_Expiry_Notification.html
# Quota exceeded. Retrying in 10 seconds...
# HTML file created: samples\Proximus_Alice_Johnson_phishing_email_Exclusive_Training_Webinar.html
# ...

# %%
# Loop through each company and generate emails
for company, branding in companies.items():
    for employee in employees:
        for phishing_example in phishing_examples:
            # Gemini prompt for generating phishing email content
            gemini_prompt = f"""
                                I am working on creating a realistic phishing email scenario to train employees effectively. 
                                The email should be composed in a professional, convincing tone, without any placeholders, salutation, or greetings such as '[insert fake phone number here]' or similar text. 
                                The content must focus on the specific theme: {phishing_example['Reason']}, and should make it seem like an urgent, legitimate communication.

                                The email should:  
                                - Be concise and professional (no more than 10 lines).  
                                - Use **bold text** to highlight important details such as the reason, actions to take, or any urgency.  
                                - Mimic a real corporate email with a proper signature.  

                                Here is the recipient's profile for context:
                                - First Name: {employee['first_name']}
                                - Last Name: {employee['last_name']}
                                - Role: {employee['role']}
                                - Department: {employee['department']}

                                The content should be clear, concise, and feel like an actual message that a customer would receive. 
                                The email should reflect the urgency of the situation and include relevant details such as dates, account activity, or instructions for the recipient to act quickly. 
                                Ensure that the message appears both credible and time-sensitive.

                                **Examples of key details to include**:
                                - Dates such as the deadline to resolve the issue
                                - A direct link to take action (e.g., resetting a password, securing an account)
                                - Emphasize the **urgency** of the situation and the **consequences** if ignored

                                **Show creativity to make the phishing attempt convincing**.
                                """

            email_body = get_gemini_completion(gemini_prompt)

            print(email_body)
# Out:
# Subject: Urgent: Review of Suspicious Account Activity
#
# Your account has been flagged due to unusual login attempts detected on **October 26th, 2023, at 10:15 PM PST**. Immediate action is required to secure your account.
#
# Failure to verify your recent activity within **24 hours** may result in temporary suspension of your account access.
#
# Please review the activity log and confirm your identity immediately via the following link: [fictitious-security-portal.com/verify]
#
# This is a mandatory security measure for all users.
#
# Regards,
#
# Security Operations Team
#
# Subject: Urgent: Your Company Account Password Expires in 24 Hours
#
# Your company account password is set to expire within the next 24 hours. **Failure to update your password will result in account lockout.**
#
# To avoid interruption of service, please reset your password immediately via the following secure link: [insert-fake-link-here].
#
# ...
